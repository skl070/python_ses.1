# %%
## the random number compare to user input game 

import random
num = random.randint(1,10)
print(num)
chances=eval(input("enter how many chances you want:"))

     

for i in range(chances):
    user= eval(input("ente the number"))
    if user == num :
        print("you won the game")
        break
    elif chances-1-i==0:
         print("pls try again after 10 mins")
            

    else:
        print("pending chance is {}".format(chances-1-i))
        print("you lost")
        print("*" * 5)
# Out:
# 9
# pending chance is 2
# you lost
# *****
# pending chance is 1
# you lost
# *****
# pls try again after 10 mins

# %%
## wsp ask the user get the sum of 10 natural numbrers

num = eval(input("enter the number"))

a= 0

for  i in range(num):
    print("{}+{} is:".format(a,i))
    a= a+i
    print(a)
# Out:
# 0+0 is:
# 0
# 0+1 is:
# 1
# 1+2 is:
# 3
# 3+3 is:
# 6
# 6+4 is:
# 10
