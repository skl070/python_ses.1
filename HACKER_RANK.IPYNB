# %%
n = int(input())
if n%2 == 0  and 2 <= n <= 5 :
    print("Not Weird") 
elif 6 <= n <=20:
    print("Weird") 
elif n > 20:
    print("Not Weird") 
else: 
    print("Weird")
# Out:
# Not Weird

# %%
n= int(input())
if n % 2 == 1:
    print("Weird")  # 29 goes here
elif n % 2 == 0 and 2 <= n <= 5:
    print("Not Weird")
elif n % 2 == 0 and 6 <= n <= 20:
    print("Weird")
else:
    print("Not Weird")

# %%
def is_leap(year):
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):## for leap all condition is mandatory!
        return True
    else:
        return False

year = int(input())
print(is_leap(year))
# Out:
# False
