# %%
list1= [1,2,3,4,5]
max(list1)
# Out:
# 5

# %%
print(len(list1))
# Out:
# 5

# %%
list2=['A','B','C','D','E','F','G',0,8]
for i in range(len(list2)):
    print(i,list2[i])
# Out:
# 0 A
# 1 B
# 2 C
# 3 D
# 4 E
# 5 F
# 6 G
# 7 0
# 8 8

# %%
for i in range(len(list2)):
    print("postive index{} and negative index is {}: for an element {}".format(i,i-len(list2),list2[i]))
# Out:
# postive index0 and negative index is -9: for an element A
# postive index1 and negative index is -8: for an element B
# postive index2 and negative index is -7: for an element C
# postive index3 and negative index is -6: for an element D
# postive index4 and negative index is -5: for an element E
# postive index5 and negative index is -4: for an element F
# postive index6 and negative index is -3: for an element G
# postive index7 and negative index is -2: for an element 0
# postive index8 and negative index is -1: for an element 8

# %%
#wap fidn the element which are  having 
list = ['app#e','B#ll','C#t','Ab','Cd','Ef']

for i in list:
    if '#' in i:
        print(i)
# Out:
# app#e
# B#ll
# C#t

# %%
# retrive the ball using index:

list1= [1,2,3,['apple','Ball']]

# list1[3][1]

for i in list1:
    if type(i)==list:
        for value in i:
            if value =='Ball':
                print(value)

# %%
list1 = [1, 2, 3, ['apple', 'Ball']]

for i in list1:
    if isinstance(i, type(list)):
        for value in i:
            if value == 'Ball':
                print(value)
# Out:
# Ball

# %%
list2=[[[[[[[["cherry"]]]]]]]]

list2[0][0][0][0][0][0][0][0]
# Out:
# 'cherry'

# %%
#wap to retrive the car
list3=[[[['a','b',[[[1,2,3,['car','bike']]]]]]]]

list3[0][0][0][2][0][0][3][1]
# Out:
# 'bike'

# %%
list1=[1,2,3,4]

list2=list1.copy()
list2
# Out:
# [1, 2, 3, 4]

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
list1=['a','b','c']
list2=[1,2,3]
list1.extend(list2)

# %%
list1
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
list1.append('abd')

# %%
list1
# Out:
# ['a', 'b', 'c', 1, 2, 3, 'abd']
